# %% [markdown]
# EDA

# %%
import pandas as pd
import numpy as np

# Display all rows
pd.set_option('display.max_rows', None)

# Load the dataset
file_path = 'airbnb_Chicago.csv'
df = pd.read_csv(file_path)

# List of columns to select
columns_to_select = [
    "Airbnb Host ID",
    "Airbnb Property ID",
    "City_x",
    "superhost_period_all",
    "Scraped Date",
    "host_is_superhost_in_period",
    "prev_host_is_superhost_in_period",
    "Superhost",
    "prev_host_is_superhost",
    "superhost_change",
    "superhost_change_lose_superhost",
    "superhost_change_gain_superhost",
    "rating_ave_pastYear",
    "numReviews_pastYear",
    "numCancel_pastYear",
    "num_5_star_Rev_pastYear",
    "prop_5_StarReviews_pastYear",
    "prev_rating_ave_pastYear",
    "prev_numReviews_pastYear",
    "prev_numCancel_pastYear",
    "prev_num_5_star_Rev_pastYear",
    "prev_prop_5_StarReviews_pastYear",
    "numReservedDays_pastYear",
    "numReserv_pastYear",
    "prev_numReservedDays_pastYear",
    "prev_numReserv_pastYear",
    "available_days",
    "available_days_aveListedPrice",
    "booked_days",
    "booked_days_avePrice",
    "prev_available_days",
    "prev_available_days_aveListedPrice",
    "prev_booked_days",
    "prev_booked_days_avePrice",
    "Property Type",
    "Listing Type",
    "Created Date",
    "Zipcode",
    "Bedrooms",
    "Bathrooms",
    "Neighborhood",
    "Max Guests",
    "Cleaning Fee (USD)",
    "Minimum Stay",
    "Number of Photos",
    "Latitude",
    "Longitude",
    "Pets Allowed",
    "Instantbook Enabled",
    "prev_Instantbook Enabled",
    "Nightly Rate",
    "prev_Nightly Rate",
    "Number of Reviews",
    "prev_Number of Reviews",
    "Rating Overall",
    "prev_Rating Overall",
    "revenue",
    "occupancy_rate",
    "prev_revenue",
    "prev_occupancy_rate",
    "census_tract",
    "tract_total_pop",
    "tract_white_perc",
    "tract_black_perc",
    "tract_asian_perc",
    "tract_housing_units",
    "zip_total_population",
    "zip_hispanic_or_latino_anyrace",
    "zip_hispanic_or_latino_anyrace_percent",
    "zip_white_nothispanic",
    "zip_white_nothispanic_percent",
    "zip_black_nothispanic",
    "zip_black_nothispanic_percent",
    "zip_asian_nothispanic",
    "zip_asian_nothispanic_percent",
    "tract_count_obs",
    "tract_unique_prices",
    "Nightly Rate_tractQuartile",
    "prev_Nightly Rate_tractQuartile",
    "available_days_aveListedPrice_tractQuartile",
    "prev_available_days_aveListedPrice_tractQuartile",
    "tract_superhosts",
    "tract_superhosts_ratio",
    "tract_prev_superhosts",
    "tract_prev_superhosts_ratio",
    "tract_price_variance",
    "tractQuartilePrice_variance",
    "prev_host_is_superhost1",
    "prev_year_superhosts",
    "booked_days_period_city",
    "revenue_period_city",
    "booked_days_period_tract",
    "revenue_period_tract",
    "tract_booking_share",
    "tract_revenue_share"
]

# Filter the DataFrame
filtered_df = df[columns_to_select]

filtered_df.to_csv('airbnb_Chicago_selected_columns.csv')

# %%
filtered_df = pd.read_csv('airbnb_Chicago_selected_columns.csv')
# Out:
# /var/folders/66/kjdgfk_530v31znwf93fdr6h0000gn/T/ipykernel_14800/4279358966.py:1: DtypeWarning: Columns (48) have mixed types. Specify dtype option on import or set low_memory=False.
#   filtered_df = pd.read_csv('airbnb_Chicago_selected_columns.csv')

# %% [markdown]
# Checking for nulls

# %%
import pandas as pd

# Display all rows
pd.set_option('display.max_rows', None)

# Check missing values again
missing_values = filtered_df.isnull().sum()
missing_percentage = (missing_values / len(filtered_df)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})

print(missing_summary.sort_values(by='Percentage', ascending=False))
# Out:
#                                                   Missing Values  Percentage
# prev_revenue                                               40293   33.523025
# prev_occupancy_rate                                        40293   33.523025
# prev_booked_days_avePrice                                  40292   33.522193
# prev_booked_days                                           40292   33.522193
# booked_days                                                38104   31.701818
# booked_days_avePrice                                       38104   31.701818
# revenue                                                    38104   31.701818
# occupancy_rate                                             38104   31.701818
# prev_rating_ave_pastYear                                   29172   24.270560
# prev_prop_5_StarReviews_pastYear                           29172   24.270560
# prev_num_5_star_Rev_pastYear                               28296   23.541745
# prev_numCancel_pastYear                                    28296   23.541745
# prev_numReviews_pastYear                                   28296   23.541745
# prev_Rating Overall                                        25760   21.431840
# Cleaning Fee (USD)                                         24156   20.097342
# prop_5_StarReviews_pastYear                                19845   16.510670
# rating_ave_pastYear                                        19845   16.510670
# available_days_aveListedPrice_tractQuartile                19644   16.343442
# num_5_star_Rev_pastYear                                    18798   15.639586
# numReviews_pastYear                                        18798   15.639586
# numCancel_pastYear                                         18798   15.639586
# prev_available_days_aveListedPrice_tractQuartile           16331   13.587088
# prev_Nightly Rate_tractQuartile                            15141   12.597030
# available_days                                             15025   12.500520
# available_days_aveListedPrice                              15025   12.500520
# Rating Overall                                             14776   12.293357
# prev_numReservedDays_pastYear                              14332   11.923957
# prev_numReserv_pastYear                                    14332   11.923957
# prev_available_days_aveListedPrice                         11727    9.756645
# prev_available_days                                        11261    9.368942
# prev_Nightly Rate                                           9846    8.191689
# prev_Number of Reviews                                      9715    8.082699
# tractQuartilePrice_variance                                 5335    4.438621
# Nightly Rate_tractQuartile                                  5335    4.438621
# tract_price_variance                                        4489    3.734764
# numReserv_pastYear                                          3514    2.923583
# numReservedDays_pastYear                                    3514    2.923583
# Neighborhood                                                1146    0.953451
# Bathrooms                                                     47    0.039103
# Number of Reviews                                             18    0.014976
# Bedrooms                                                      11    0.009152
# Max Guests                                                     8    0.006656
# Number of Photos                                               6    0.004992
# Minimum Stay                                                   4    0.003328
# tract_housing_units                                            1    0.000832
# zip_white_nothispanic_percent                                  1    0.000832
# tract_black_perc                                               1    0.000832
# tract_asian_perc                                               1    0.000832
# tract_white_perc                                               1    0.000832
# zip_black_nothispanic                                          1    0.000832
# zip_hispanic_or_latino_anyrace_percent                         1    0.000832
# zip_white_nothispanic                                          1    0.000832
# tract_total_pop                                                1    0.000832
# zip_hispanic_or_latino_anyrace                                 1    0.000832
# zip_total_population                                           1    0.000832
# census_tract                                                   1    0.000832
# tract_revenue_share                                            1    0.000832
# tract_superhosts                                               1    0.000832
# zip_asian_nothispanic_percent                                  1    0.000832
# tract_count_obs                                                1    0.000832
# tract_unique_prices                                            1    0.000832
# zip_asian_nothispanic                                          1    0.000832
# tract_superhosts_ratio                                         1    0.000832
# Property Type                                                  1    0.000832
# tract_prev_superhosts                                          1    0.000832
# tract_prev_superhosts_ratio                                    1    0.000832
# prev_host_is_superhost1                                        1    0.000832
# prev_year_superhosts                                           1    0.000832
# booked_days_period_city                                        1    0.000832
# revenue_period_city                                            1    0.000832
# booked_days_period_tract                                       1    0.000832
# revenue_period_tract                                           1    0.000832
# tract_booking_share                                            1    0.000832
# zip_black_nothispanic_percent                                  1    0.000832
# Unnamed: 0                                                     0    0.000000
# Nightly Rate                                                   0    0.000000
# superhost_change                                               0    0.000000
# Airbnb Property ID                                             0    0.000000
# City_x                                                         0    0.000000
# superhost_period_all                                           0    0.000000
# Scraped Date                                                   0    0.000000
# host_is_superhost_in_period                                    0    0.000000
# prev_host_is_superhost_in_period                               0    0.000000
# Superhost                                                      0    0.000000
# prev_host_is_superhost                                         0    0.000000
# superhost_change_lose_superhost                                0    0.000000
# prev_Instantbook Enabled                                       0    0.000000
# superhost_change_gain_superhost                                0    0.000000
# Listing Type                                                   0    0.000000
# Created Date                                                   0    0.000000
# Zipcode                                                        0    0.000000
# Latitude                                                       0    0.000000
# Longitude                                                      0    0.000000
# Airbnb Host ID                                                 0    0.000000
# Instantbook Enabled                                            0    0.000000
# Pets Allowed                                                   0    0.000000

# %%
# List of columns where null values should be checked
columns_to_check = [
    "tractQuartilePrice_variance",
    "Nightly Rate_tractQuartile",
    "tract_price_variance",
    "numReserv_pastYear",
    "numReservedDays_pastYear",
    "Neighborhood",
    "Bathrooms",
    "Number of Reviews",
    "Bedrooms",
    "Max Guests",
    "Number of Photos",
    "Minimum Stay",
    "Property Type"
]

# Drop rows where any of the specified columns have null values
filtered_df = filtered_df.dropna(subset=columns_to_check)

# %%
import pandas as pd

# Display all rows
pd.set_option('display.max_rows', None)

# Check missing values again
missing_values = filtered_df.isnull().sum()
missing_percentage = (missing_values / len(filtered_df)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})

print(missing_summary.sort_values(by='Percentage', ascending=False))
# Out:
#                                                   Missing Values  Percentage
# prev_occupancy_rate                                        34776   31.436216
# prev_revenue                                               34776   31.436216
# prev_booked_days_avePrice                                  34776   31.436216
# prev_booked_days                                           34776   31.436216
# occupancy_rate                                             32766   29.619251
# revenue                                                    32766   29.619251
# booked_days_avePrice                                       32766   29.619251
# booked_days                                                32766   29.619251
# prev_rating_ave_pastYear                                   24368   22.027770
# prev_prop_5_StarReviews_pastYear                           24368   22.027770
# prev_num_5_star_Rev_pastYear                               23642   21.371493
# prev_numCancel_pastYear                                    23642   21.371493
# prev_numReviews_pastYear                                   23642   21.371493
# prev_Rating Overall                                        22497   20.336455
# Cleaning Fee (USD)                                         20724   18.733729
# prop_5_StarReviews_pastYear                                15456   13.971652
# rating_ave_pastYear                                        15456   13.971652
# numCancel_pastYear                                         14586   13.185204
# numReviews_pastYear                                        14586   13.185204
# num_5_star_Rev_pastYear                                    14586   13.185204
# Rating Overall                                             12346   11.160327
# available_days_aveListedPrice_tractQuartile                11971   10.821341
# available_days                                             11421   10.324161
# available_days_aveListedPrice                              11421   10.324161
# prev_numReserv_pastYear                                    10732    9.701331
# prev_numReservedDays_pastYear                              10732    9.701331
# prev_Nightly Rate_tractQuartile                             9730    8.795560
# prev_Nightly Rate                                           9173    8.292052
# prev_Number of Reviews                                      9051    8.181769
# prev_available_days_aveListedPrice_tractQuartile            8744    7.904252
# prev_available_days_aveListedPrice                          8312    7.513740
# prev_available_days                                         7866    7.110573
# zip_white_nothispanic                                          0    0.000000
# tract_asian_perc                                               0    0.000000
# zip_asian_nothispanic                                          0    0.000000
# tract_housing_units                                            0    0.000000
# zip_total_population                                           0    0.000000
# zip_hispanic_or_latino_anyrace                                 0    0.000000
# zip_white_nothispanic_percent                                  0    0.000000
# zip_black_nothispanic                                          0    0.000000
# zip_black_nothispanic_percent                                  0    0.000000
# zip_hispanic_or_latino_anyrace_percent                         0    0.000000
# Unnamed: 0                                                     0    0.000000
# zip_asian_nothispanic_percent                                  0    0.000000
# tractQuartilePrice_variance                                    0    0.000000
# tract_booking_share                                            0    0.000000
# revenue_period_tract                                           0    0.000000
# booked_days_period_tract                                       0    0.000000
# revenue_period_city                                            0    0.000000
# booked_days_period_city                                        0    0.000000
# prev_year_superhosts                                           0    0.000000
# prev_host_is_superhost1                                        0    0.000000
# tract_price_variance                                           0    0.000000
# tract_count_obs                                                0    0.000000
# tract_prev_superhosts_ratio                                    0    0.000000
# tract_prev_superhosts                                          0    0.000000
# tract_superhosts_ratio                                         0    0.000000
# tract_superhosts                                               0    0.000000
# tract_white_perc                                               0    0.000000
# Nightly Rate_tractQuartile                                     0    0.000000
# tract_unique_prices                                            0    0.000000
# tract_black_perc                                               0    0.000000
# Pets Allowed                                                   0    0.000000
# tract_total_pop                                                0    0.000000
# Listing Type                                                   0    0.000000
# Airbnb Property ID                                             0    0.000000
# City_x                                                         0    0.000000
# superhost_period_all                                           0    0.000000
# Scraped Date                                                   0    0.000000
# host_is_superhost_in_period                                    0    0.000000
# prev_host_is_superhost_in_period                               0    0.000000
# Superhost                                                      0    0.000000
# prev_host_is_superhost                                         0    0.000000
# superhost_change                                               0    0.000000
# superhost_change_lose_superhost                                0    0.000000
# superhost_change_gain_superhost                                0    0.000000
# numReservedDays_pastYear                                       0    0.000000
# numReserv_pastYear                                             0    0.000000
# Property Type                                                  0    0.000000
# Created Date                                                   0    0.000000
# census_tract                                                   0    0.000000
# Zipcode                                                        0    0.000000
# Bedrooms                                                       0    0.000000
# Bathrooms                                                      0    0.000000
# Neighborhood                                                   0    0.000000
# Max Guests                                                     0    0.000000
# Minimum Stay                                                   0    0.000000
# Number of Photos                                               0    0.000000
# Latitude                                                       0    0.000000
# Longitude                                                      0    0.000000
# Airbnb Host ID                                                 0    0.000000
# Instantbook Enabled                                            0    0.000000
# prev_Instantbook Enabled                                       0    0.000000
# Nightly Rate                                                   0    0.000000
# Number of Reviews                                              0    0.000000
# tract_revenue_share                                            0    0.000000

# %%
common_missing_records = [
    'Rating Overall', 
    'rating_ave_pastYear',
    'numReserv_pastYear',
    'prop_5_StarReviews_pastYear']

# Dropping rows where any of the specified columns have null values
filtered_df.dropna(subset=common_missing_records, inplace=True)

# %%
import pandas as pd

# Display all rows
pd.set_option('display.max_rows', None)

# Check missing values again
missing_values = filtered_df.isnull().sum()
missing_percentage = (missing_values / len(filtered_df)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})

print(missing_summary.sort_values(by='Percentage', ascending=False))
# Out:
#                                                   Missing Values  Percentage
# booked_days                                                22297   25.362574
# occupancy_rate                                             22297   25.362574
# booked_days_avePrice                                       22297   25.362574
# revenue                                                    22297   25.362574
# prev_revenue                                               20992   23.878152
# prev_booked_days_avePrice                                  20992   23.878152
# prev_occupancy_rate                                        20992   23.878152
# prev_booked_days                                           20992   23.878152
# Cleaning Fee (USD)                                         13676   15.556289
# prev_prop_5_StarReviews_pastYear                            8942   10.171419
# prev_rating_ave_pastYear                                    8942   10.171419
# prev_num_5_star_Rev_pastYear                                8767    9.972359
# prev_numCancel_pastYear                                     8767    9.972359
# prev_numReviews_pastYear                                    8767    9.972359
# available_days_aveListedPrice_tractQuartile                 7653    8.705197
# prev_Rating Overall                                         7575    8.616473
# available_days_aveListedPrice                               7187    8.175128
# available_days                                              7187    8.175128
# prev_numReserv_pastYear                                     6882    7.828194
# prev_numReservedDays_pastYear                               6882    7.828194
# prev_available_days_aveListedPrice_tractQuartile            5143    5.850102
# prev_available_days_aveListedPrice                          4780    5.437194
# prev_available_days                                         4537    5.160784
# prev_Nightly Rate_tractQuartile                             4476    5.091397
# prev_Nightly Rate                                           4098    4.661427
# prev_Number of Reviews                                      4036    4.590902
# tract_asian_perc                                               0    0.000000
# tract_housing_units                                            0    0.000000
# zip_black_nothispanic                                          0    0.000000
# tract_black_perc                                               0    0.000000
# tract_white_perc                                               0    0.000000
# zip_total_population                                           0    0.000000
# zip_hispanic_or_latino_anyrace                                 0    0.000000
# tract_total_pop                                                0    0.000000
# census_tract                                                   0    0.000000
# zip_hispanic_or_latino_anyrace_percent                         0    0.000000
# zip_white_nothispanic                                          0    0.000000
# zip_white_nothispanic_percent                                  0    0.000000
# booked_days_period_tract                                       0    0.000000
# zip_black_nothispanic_percent                                  0    0.000000
# tract_superhosts_ratio                                         0    0.000000
# booked_days_period_city                                        0    0.000000
# prev_year_superhosts                                           0    0.000000
# prev_host_is_superhost1                                        0    0.000000
# tractQuartilePrice_variance                                    0    0.000000
# tract_price_variance                                           0    0.000000
# tract_prev_superhosts_ratio                                    0    0.000000
# tract_prev_superhosts                                          0    0.000000
# tract_superhosts                                               0    0.000000
# zip_asian_nothispanic                                          0    0.000000
# Nightly Rate_tractQuartile                                     0    0.000000
# tract_unique_prices                                            0    0.000000
# revenue_period_tract                                           0    0.000000
# tract_booking_share                                            0    0.000000
# revenue_period_city                                            0    0.000000
# tract_count_obs                                                0    0.000000
# zip_asian_nothispanic_percent                                  0    0.000000
# Unnamed: 0                                                     0    0.000000
# Pets Allowed                                                   0    0.000000
# Rating Overall                                                 0    0.000000
# numReservedDays_pastYear                                       0    0.000000
# num_5_star_Rev_pastYear                                        0    0.000000
# numCancel_pastYear                                             0    0.000000
# numReviews_pastYear                                            0    0.000000
# rating_ave_pastYear                                            0    0.000000
# superhost_change_gain_superhost                                0    0.000000
# superhost_change_lose_superhost                                0    0.000000
# superhost_change                                               0    0.000000
# prev_host_is_superhost                                         0    0.000000
# Superhost                                                      0    0.000000
# prev_host_is_superhost_in_period                               0    0.000000
# host_is_superhost_in_period                                    0    0.000000
# Scraped Date                                                   0    0.000000
# superhost_period_all                                           0    0.000000
# City_x                                                         0    0.000000
# Airbnb Property ID                                             0    0.000000
# prop_5_StarReviews_pastYear                                    0    0.000000
# numReserv_pastYear                                             0    0.000000
# Number of Reviews                                              0    0.000000
# Property Type                                                  0    0.000000
# Nightly Rate                                                   0    0.000000
# prev_Instantbook Enabled                                       0    0.000000
# Instantbook Enabled                                            0    0.000000
# Airbnb Host ID                                                 0    0.000000
# Longitude                                                      0    0.000000
# Latitude                                                       0    0.000000
# Number of Photos                                               0    0.000000
# Minimum Stay                                                   0    0.000000
# Max Guests                                                     0    0.000000
# Neighborhood                                                   0    0.000000
# Bathrooms                                                      0    0.000000
# Bedrooms                                                       0    0.000000
# Zipcode                                                        0    0.000000
# Created Date                                                   0    0.000000
# Listing Type                                                   0    0.000000
# tract_revenue_share                                            0    0.000000

# %%
from sklearn.experimental import enable_iterative_imputer  # Required to enable IterativeImputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import HistGradientBoostingRegressor

# Columns to impute
columns_to_impute = [
    "booked_days",
    "occupancy_rate",
    "booked_days_avePrice",
    "revenue",
    "prev_revenue",
    "prev_booked_days_avePrice",
    "prev_occupancy_rate",
    "prev_booked_days",
    "Cleaning Fee (USD)",
    "prev_prop_5_StarReviews_pastYear",
    "prev_rating_ave_pastYear",
    "prev_num_5_star_Rev_pastYear",
    "prev_numCancel_pastYear",
    "prev_numReviews_pastYear",
    "available_days_aveListedPrice_tractQuartile",
    "prev_Rating Overall",
    "available_days_aveListedPrice",
    "available_days",
    "prev_numReserv_pastYear",
    "prev_numReservedDays_pastYear",
    "prev_available_days_aveListedPrice_tractQuartile",
    "prev_available_days_aveListedPrice",
    "prev_available_days",
    "prev_Nightly Rate_tractQuartile",
    "prev_Nightly Rate",
    "prev_Number of Reviews"
]

# Initialize IterativeImputer with HistGradientBoostingRegressor
imputer = IterativeImputer(estimator=HistGradientBoostingRegressor(), max_iter=20, random_state=0)

# Apply imputation only on the selected columns
df_imputed = filtered_df.copy()
df_imputed[columns_to_impute] = imputer.fit_transform(df_imputed[columns_to_impute])

df_imputed = df_imputed.drop(columns=["Unnamed: 0"])
# Out:
# /Users/vishnuanand/Library/Python/3.9/lib/python/site-packages/sklearn/impute/_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
import pandas as pd

# Display all rows
pd.set_option('display.max_rows', None)

# Check missing values again
missing_values = df_imputed.isnull().sum()
missing_percentage = (missing_values / len(df_imputed)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})

print(missing_summary.sort_values(by='Percentage', ascending=False))
# Out:
#                                                   Missing Values  Percentage
# Airbnb Host ID                                                 0         0.0
# census_tract                                                   0         0.0
# zip_white_nothispanic                                          0         0.0
# zip_hispanic_or_latino_anyrace_percent                         0         0.0
# zip_hispanic_or_latino_anyrace                                 0         0.0
# zip_total_population                                           0         0.0
# tract_housing_units                                            0         0.0
# tract_asian_perc                                               0         0.0
# tract_black_perc                                               0         0.0
# tract_white_perc                                               0         0.0
# tract_total_pop                                                0         0.0
# prev_occupancy_rate                                            0         0.0
# zip_black_nothispanic                                          0         0.0
# prev_revenue                                                   0         0.0
# occupancy_rate                                                 0         0.0
# revenue                                                        0         0.0
# prev_Rating Overall                                            0         0.0
# Rating Overall                                                 0         0.0
# prev_Number of Reviews                                         0         0.0
# Number of Reviews                                              0         0.0
# prev_Nightly Rate                                              0         0.0
# Nightly Rate                                                   0         0.0
# zip_white_nothispanic_percent                                  0         0.0
# zip_black_nothispanic_percent                                  0         0.0
# Instantbook Enabled                                            0         0.0
# tract_prev_superhosts_ratio                                    0         0.0
# tract_booking_share                                            0         0.0
# revenue_period_tract                                           0         0.0
# booked_days_period_tract                                       0         0.0
# revenue_period_city                                            0         0.0
# booked_days_period_city                                        0         0.0
# prev_year_superhosts                                           0         0.0
# prev_host_is_superhost1                                        0         0.0
# tractQuartilePrice_variance                                    0         0.0
# tract_price_variance                                           0         0.0
# tract_prev_superhosts                                          0         0.0
# zip_asian_nothispanic                                          0         0.0
# tract_superhosts_ratio                                         0         0.0
# tract_superhosts                                               0         0.0
# prev_available_days_aveListedPrice_tractQuartile               0         0.0
# available_days_aveListedPrice_tractQuartile                    0         0.0
# prev_Nightly Rate_tractQuartile                                0         0.0
# Nightly Rate_tractQuartile                                     0         0.0
# tract_unique_prices                                            0         0.0
# tract_count_obs                                                0         0.0
# zip_asian_nothispanic_percent                                  0         0.0
# prev_Instantbook Enabled                                       0         0.0
# Pets Allowed                                                   0         0.0
# Airbnb Property ID                                             0         0.0
# rating_ave_pastYear                                            0         0.0
# prev_prop_5_StarReviews_pastYear                               0         0.0
# prev_num_5_star_Rev_pastYear                                   0         0.0
# prev_numCancel_pastYear                                        0         0.0
# prev_numReviews_pastYear                                       0         0.0
# prev_rating_ave_pastYear                                       0         0.0
# prop_5_StarReviews_pastYear                                    0         0.0
# num_5_star_Rev_pastYear                                        0         0.0
# numCancel_pastYear                                             0         0.0
# numReviews_pastYear                                            0         0.0
# superhost_change_gain_superhost                                0         0.0
# numReserv_pastYear                                             0         0.0
# superhost_change_lose_superhost                                0         0.0
# superhost_change                                               0         0.0
# prev_host_is_superhost                                         0         0.0
# Superhost                                                      0         0.0
# prev_host_is_superhost_in_period                               0         0.0
# host_is_superhost_in_period                                    0         0.0
# Scraped Date                                                   0         0.0
# superhost_period_all                                           0         0.0
# City_x                                                         0         0.0
# numReservedDays_pastYear                                       0         0.0
# prev_numReservedDays_pastYear                                  0         0.0
# Longitude                                                      0         0.0
# Created Date                                                   0         0.0
# Latitude                                                       0         0.0
# Number of Photos                                               0         0.0
# Minimum Stay                                                   0         0.0
# Cleaning Fee (USD)                                             0         0.0
# Max Guests                                                     0         0.0
# Neighborhood                                                   0         0.0
# Bathrooms                                                      0         0.0
# Bedrooms                                                       0         0.0
# Zipcode                                                        0         0.0
# Listing Type                                                   0         0.0
# prev_numReserv_pastYear                                        0         0.0
# Property Type                                                  0         0.0
# prev_booked_days_avePrice                                      0         0.0
# prev_booked_days                                               0         0.0
# prev_available_days_aveListedPrice                             0         0.0
# prev_available_days                                            0         0.0
# booked_days_avePrice                                           0         0.0
# booked_days                                                    0         0.0
# available_days_aveListedPrice                                  0         0.0
# available_days                                                 0         0.0
# tract_revenue_share                                            0         0.0

# %% [markdown]
# Outlier handling

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

# Set a visual theme
sns.set_theme(style="whitegrid")

# Get numerical columns
numerical_columns = df_imputed.select_dtypes(include='number').columns

# Determine the grid size
n_cols = 3  # Number of plots per row
n_rows = math.ceil(len(numerical_columns) / n_cols)  # Number of rows needed

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4 * n_rows))
axes = axes.flatten()  # Flatten axes for easy indexing

# Plot each numerical column
for i, column in enumerate(numerical_columns):
    sns.boxplot(
        x=df_imputed[column],
        ax=axes[i],
        color="skyblue",
        showmeans=True,
        meanline=True,
        meanprops={"color": "red", "linestyle": "--"}
    )
    axes[i].set_title(f'{column}', fontsize=12)
    axes[i].set_xlabel('')
    axes[i].grid(axis="x", linestyle="--", alpha=0.7)

# Remove unused subplots
for j in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation Analysis
